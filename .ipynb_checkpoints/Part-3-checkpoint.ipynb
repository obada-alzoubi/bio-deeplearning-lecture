# %%
#pip install mdtraj
#conda install -y -c conda-forge pdbfixer
# conda install -y boost-cpp boost py-boost
#pip install rdkit
# pip install git+https://github.com/samoturk/mol2vec
#pip install matminer
#pip install mordred
#pip install networkx[default]
#conda install -c conda-forge openmm
#

#pip install pymatgen

# %%
import deepchem as dc
# import image module
# import image module
from IPython.display import Image
import rdkit
# Out:
# 2023-03-12 19:57:28.741128: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-12 19:57:28.837858: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-12 19:57:28.843199: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-12 19:57:28.843210: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-12 19:57:29.315934: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-12 19:57:29.316006: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-12 19:57:29.316011: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Skipped loading some PyTorch models, missing a dependency. No module named 'torch'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch'
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'torch'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'

# %% [markdown]
# Understanding the details of how, where, and when molecules bind to proteins is critical
# to understanding their functions and developing drugs. If we can coopt the signaling
# mechanisms of cells in the human body, we can induce desired medical
# responses in the body.

# %% [markdown]
# ### Biophysical Featurizations

# %% [markdown]
# #### From Molecules to Features

# %% [markdown]
# grid featurization, explicitly searches a 3D structure
# for the presence of critical physical interactions such as hydrogen bonds and salt
# bridges (more on these later), which are known to play an important role in determining
# protein structure

# %% [markdown]
# DeepChem has such a featurizer available. Its RdkitGridFeaturizer

# %% [markdown]
# #### Hydrogen bonds

# %%
Image('../AUB-Lecture/assets/Hydrogen-bonding-in-water-2D.png')

# %% [markdown]
# #### Salt bridges

# %%
Image('../AUB-Lecture/assets/800px-Revisited_Glutamic_Acid_Lysine_salt_bridge.png')

# %% [markdown]
# #### Pi-stacking interactions

# %%
Image('../AUB-Lecture/assets/510px-Double_Mutant_Cycle.png')

# %% [markdown]
# #### Fingerpint

# %%
Image('../AUB-Lecture/assets/Fingerprint.png')

# %% [markdown]
# #### Cation-π

# %%
Image('../AUB-Lecture/assets/Benzene-sodium.png')

# %% [markdown]
# ### Atomic Featurization

# %% [markdown]
# featurization for a given molecule could simply involve
# computing this (N, 3) array and passing it to a suitable machine learning algorithm.
# The model could then learn for itself what features were important, rather than relying
# on a human to select them and code them by hand.
# In fact, this turns out to work—with a couple of extra steps. The (N, 3) position
# array doesn’t distinguish atom types, so you also need to provide another array that
# lists the atomic number of each atom.

# %% [markdown]
# DeepChem provides a dc.feat.ComplexNeighborListFragmentAtomicCoordinates

# %% [markdown]
# ### Protein-Ligand

# %%
Image('../AUB-Lecture/assets/Myoglobin_and_heme.png')

# %% [markdown]
# #### PDBBind Dataset

# %% [markdown]
# The PDBBind dataset contains a large number of biomolecular crystal structures and
# their binding affinities.

# %% [markdown]
# A binding affinity is the experimentally measured affinity of two molecules to form a complex, with
# the two molecules interacting. If it is energetically favorable to form such a complex,
# the molecules will spend more time in that configuration as opposed to another one.

# %%
import os
import numpy as np
import pandas as pd

import deepchem as dc
from deepchem.molnet.load_function.molnet_loader import TransformerGenerator, _MolnetLoader
from deepchem.data import Dataset
from typing import List, Optional, Tuple, Union

DATASETS_URL = "https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/"
PDBBIND_URL = DATASETS_URL + "pdbbindv2019/"
PDBBIND_TASKS = ['-logKd/Ki']


class _PDBBindLoader(_MolnetLoader):

    def __init__(self,
                 *args,
                 pocket: bool = True,
                 set_name: str = 'core',
                 **kwargs):
        super(_PDBBindLoader, self).__init__(*args, **kwargs)
        self.pocket = pocket
        self.set_name = set_name
        if set_name == 'general':
            self.name = 'pdbbind_v2019_other_PL'  # 'general' set folder name
        elif set_name == 'refined':
            self.name = 'pdbbind_v2019_refined'
        elif set_name == 'core':
            self.name = 'pdbbind_v2013_core_set'

    def create_dataset(self) -> Dataset:
        if self.set_name not in ['refined', 'general', 'core']:
            raise ValueError(
                "Only 'refined', 'general', and 'core' are supported for set_name."
            )

        filename = self.name + '.tar.gz'
        data_folder = os.path.join(self.data_dir, self.name)
        dataset_file = os.path.join(self.data_dir, filename)
        if not os.path.exists(data_folder):
            if self.set_name in ['refined', 'general']:
                dc.utils.data_utils.download_url(url=PDBBIND_URL + filename,
                                                 dest_dir=self.data_dir)
            else:
                dc.utils.data_utils.download_url(url=DATASETS_URL + filename,
                                                 dest_dir=self.data_dir)
            dc.utils.data_utils.untargz_file(dataset_file,
                                             dest_dir=self.data_dir)

        # get pdb and sdf filenames, labels and pdbids
        protein_files, ligand_files, labels, pdbs = self._process_pdbs()

        # load and featurize each complex
        features = self.featurizer.featurize(
            list(zip(ligand_files, protein_files)))
        dataset = dc.data.DiskDataset.from_numpy(features, y=labels, ids=pdbs)

        return dataset

    def _process_pdbs(
            self) -> Tuple[List[str], List[str], np.ndarray, List[str]]:
        if self.set_name == 'general':
            data_folder = os.path.join(self.data_dir, 'v2019-other-PL')
            index_labels_file = os.path.join(
                data_folder, 'index/INDEX_general_PL_data.2019')
        elif self.set_name == 'refined':
            data_folder = os.path.join(self.data_dir, 'refined-set')
            index_labels_file = os.path.join(data_folder,
                                             'index/INDEX_refined_data.2019')
        elif self.set_name == 'core':
            data_folder = os.path.join(self.data_dir, 'v2013-core')
            index_labels_file = os.path.join(data_folder,
                                             'pdbbind_v2013_core.csv')

        if self.set_name in ['general', 'refined']:
            # Extract locations of data
            with open(index_labels_file, "r") as g:
                pdbs = [line[:4] for line in g.readlines() if line[0] != "#"]
            # Extract labels
            with open(index_labels_file, "r") as g:
                labels = np.array([
                    # Lines have format
                    # PDB code, resolution, release year, -logKd/Ki, Kd/Ki, reference, ligand name
                    # The base-10 logarithm, -log kd/pk
                    float(line.split()[3])
                    for line in g.readlines()
                    if line[0] != "#"
                ])
        else:
            df = pd.read_csv(index_labels_file)
            pdbs = df.pdb_id.tolist()
            labels = np.array(df.label.tolist())

        if self.pocket:  # only load binding pocket
            protein_files = [
                os.path.join(data_folder, pdb, "%s_pocket.pdb" % pdb)
                for pdb in pdbs
            ]
        else:
            protein_files = [
                os.path.join(data_folder, pdb, "%s_protein.pdb" % pdb)
                for pdb in pdbs
            ]
        ligand_files = [
            os.path.join(data_folder, pdb, "%s_ligand.sdf" % pdb)
            for pdb in pdbs
        ]

        return (protein_files, ligand_files, labels, pdbs)


def load_pdbbind(
    featurizer: dc.feat.ComplexFeaturizer,
    splitter: Union[dc.splits.Splitter, str, None] = 'random',
    transformers: List[Union[TransformerGenerator, str]] = ['normalization'],
    reload: bool = True,
    data_dir: Optional[str] = None,
    save_dir: Optional[str] = None,
    pocket: bool = True,
    set_name: str = 'core',
    **kwargs
) -> Tuple[List[str], Tuple[Dataset, ...], List[dc.trans.Transformer]]:
    """Load PDBBind dataset.
    The PDBBind dataset includes experimental binding affinity data
    and structures for 4852 protein-ligand complexes from the "refined set"
    and 12800 complexes from the "general set" in PDBBind v2019 and 193
    complexes from the "core set" in PDBBind v2013.
    The refined set removes data with obvious problems
    in 3D structure, binding data, or other aspects and should therefore
    be a better starting point for docking/scoring studies. Details on
    the criteria used to construct the refined set can be found in [4]_.
    The general set does not include the refined set. The core set is
    a subset of the refined set that is not updated annually.
    Random splitting is recommended for this dataset.
    The raw dataset contains the columns below:
    - "ligand" - SDF of the molecular structure
    - "protein" - PDB of the protein structure
    - "CT_TOX" - Clinical trial results
    Parameters
    ----------
    featurizer: ComplexFeaturizer or str
        the complex featurizer to use for processing the data.
        Alternatively you can pass one of the names from
        dc.molnet.featurizers as a shortcut.
    splitter: Splitter or str
        the splitter to use for splitting the data into training, validation, and
        test sets.  Alternatively you can pass one of the names from
        dc.molnet.splitters as a shortcut.  If this is None, all the data
        will be included in a single dataset.
    transformers: list of TransformerGenerators or strings
        the Transformers to apply to the data.  Each one is specified by a
        TransformerGenerator or, as a shortcut, one of the names from
        dc.molnet.transformers.
    reload: bool
        if True, the first call for a particular featurizer and splitter will cache
        the datasets to disk, and subsequent calls will reload the cached datasets.
    data_dir: str
        a directory to save the raw data in
    save_dir: str
        a directory to save the dataset in
    pocket: bool (default True)
        If true, use only the binding pocket for featurization.
    set_name: str (default 'core')
        Name of dataset to download. 'refined', 'general', and 'core' are supported.
    Returns
    -------
    tasks, datasets, transformers: tuple
        tasks: list
            Column names corresponding to machine learning target variables.
        datasets: tuple
            train, validation, test splits of data as
            ``deepchem.data.datasets.Dataset`` instances.
        transformers: list
            ``deepchem.trans.transformers.Transformer`` instances applied
            to dataset.
    References
    ----------
    .. [1] Liu, Z.H. et al. Acc. Chem. Res. 2017, 50, 302-309. (PDBbind v.2016)
    .. [2] Liu, Z.H. et al. Bioinformatics, 2015, 31, 405-412. (PDBbind v.2014)
    .. [3] Li, Y. et al. J. Chem. Inf. Model., 2014, 54, 1700-1716.(PDBbind v.2013)
    .. [4] Cheng, T.J. et al. J. Chem. Inf. Model., 2009, 49, 1079-1093. (PDBbind v.2009)
    .. [5] Wang, R.X. et al. J. Med. Chem., 2005, 48, 4111-4119. (Original release)
    .. [6] Wang, R.X. et al. J. Med. Chem., 2004, 47, 2977-2980. (Original release)
    """

    loader = _PDBBindLoader(featurizer,
                            splitter,
                            transformers,
                            PDBBIND_TASKS,
                            data_dir,
                            save_dir,
                            pocket=pocket,
                            set_name=set_name,
                            **kwargs)
    return loader.load_dataset(loader.name, reload)

# %%
#featurizer = dc.feat.RdkitGridFeaturizer(voxel_width=2.0,
#                                        sanitize=True, flatten=True,
#                                        feature_types=['hbond', 'salt_bridge', 'pi_stack', 'cation_pi'])
featurizer = dc.feat.Mol2VecFingerprint()

tasks, datasets, transformers = load_pdbbind(featurizer=featurizer,
                                                        splitter="random",
                                                        set_name ='core',
                                                        pocket=True,
                                                        data_dir='data/pdbbind',
                                                        save_dir='data/pdbbind')
train_dataset, valid_dataset, test_dataset = datasets
# Out:
# Failed to featurize datapoint 0, ('data/pdbbind/v2013-core/2d3u/2d3u_ligand.sdf', 'data/pdbbind/v2013-core/2d3u/2d3u_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 1, ('data/pdbbind/v2013-core/3cyx/3cyx_ligand.sdf', 'data/pdbbind/v2013-core/3cyx/3cyx_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 2, ('data/pdbbind/v2013-core/3uo4/3uo4_ligand.sdf', 'data/pdbbind/v2013-core/3uo4/3uo4_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 3, ('data/pdbbind/v2013-core/1p1q/1p1q_ligand.sdf', 'data/pdbbind/v2013-core/1p1q/1p1q_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 4, ('data/pdbbind/v2013-core/3ag9/3ag9_ligand.sdf', 'data/pdbbind/v2013-core/3ag9/3ag9_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 5, ('data/pdbbind/v2013-core/2wtv/2wtv_ligand.sdf', 'data/pdbbind/v2013-core/2wtv/2wtv_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 6, ('data/pdbbind/v2013-core/3dxg/3dxg_ligand.sdf', 'data/pdbbind/v2013-core/3dxg/3dxg_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 7, ('data/pdbbind/v2013-core/4tmn/4tmn_ligand.sdf', 'data/pdbbind/v2013-core/4tmn/4tmn_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 8, ('data/pdbbind/v2013-core/2zcq/2zcq_ligand.sdf', 'data/pdbbind/v2013-core/2zcq/2zcq_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 9, ('data/pdbbind/v2013-core/1q8t/1q8t_ligand.sdf', 'data/pdbbind/v2013-core/1q8t/1q8t_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 10, ('data/pdbbind/v2013-core/4des/4des_ligand.sdf', 'data/pdbbind/v2013-core/4des/4des_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 11, ('data/pdbbind/v2013-core/1n1m/1n1m_ligand.sdf', 'data/pdbbind/v2013-core/1n1m/1n1m_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 12, ('data/pdbbind/v2013-core/1mq6/1mq6_ligand.sdf', 'data/pdbbind/v2013-core/1mq6/1mq6_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 13, ('data/pdbbind/v2013-core/2vl4/2vl4_ligand.sdf', 'data/pdbbind/v2013-core/2vl4/2vl4_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 14, ('data/pdbbind/v2013-core/2x97/2x97_ligand.sdf', 'data/pdbbind/v2013-core/2x97/2x97_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 15, ('data/pdbbind/v2013-core/3k5v/3k5v_ligand.sdf', 'data/pdbbind/v2013-core/3k5v/3k5v_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 16, ('data/pdbbind/v2013-core/3jvs/3jvs_ligand.sdf', 'data/pdbbind/v2013-core/3jvs/3jvs_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 17, ('data/pdbbind/v2013-core/3fcq/3fcq_ligand.sdf', 'data/pdbbind/v2013-core/3fcq/3fcq_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 18, ('data/pdbbind/v2013-core/1kel/1kel_ligand.sdf', 'data/pdbbind/v2013-core/1kel/1kel_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 19, ('data/pdbbind/v2013-core/3kgp/3kgp_ligand.sdf', 'data/pdbbind/v2013-core/3kgp/3kgp_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 20, ('data/pdbbind/v2013-core/2xy9/2xy9_ligand.sdf', 'data/pdbbind/v2013-core/2xy9/2xy9_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 21, ('data/pdbbind/v2013-core/2x00/2x00_ligand.sdf', 'data/pdbbind/v2013-core/2x00/2x00_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 22, ('data/pdbbind/v2013-core/2zx6/2zx6_ligand.sdf', 'data/pdbbind/v2013-core/2zx6/2zx6_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 23, ('data/pdbbind/v2013-core/3ao4/3ao4_ligand.sdf', 'data/pdbbind/v2013-core/3ao4/3ao4_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 24, ('data/pdbbind/v2013-core/2zxd/2zxd_ligand.sdf', 'data/pdbbind/v2013-core/2zxd/2zxd_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 25, ('data/pdbbind/v2013-core/3bfu/3bfu_ligand.sdf', 'data/pdbbind/v2013-core/3bfu/3bfu_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 26, ('data/pdbbind/v2013-core/2g70/2g70_ligand.sdf', 'data/pdbbind/v2013-core/2g70/2g70_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 27, ('data/pdbbind/v2013-core/2j78/2j78_ligand.sdf', 'data/pdbbind/v2013-core/2j78/2j78_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 28, ('data/pdbbind/v2013-core/3u9q/3u9q_ligand.sdf', 'data/pdbbind/v2013-core/3u9q/3u9q_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 29, ('data/pdbbind/v2013-core/3gbb/3gbb_ligand.sdf', 'data/pdbbind/v2013-core/3gbb/3gbb_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 30, ('data/pdbbind/v2013-core/4gid/4gid_ligand.sdf', 'data/pdbbind/v2013-core/4gid/4gid_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 31, ('data/pdbbind/v2013-core/3nox/3nox_ligand.sdf', 'data/pdbbind/v2013-core/3nox/3nox_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 32, ('data/pdbbind/v2013-core/2pcp/2pcp_ligand.sdf', 'data/pdbbind/v2013-core/2pcp/2pcp_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 33, ('data/pdbbind/v2013-core/1w3l/1w3l_ligand.sdf', 'data/pdbbind/v2013-core/1w3l/1w3l_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 34, ('data/pdbbind/v2013-core/2vvn/2vvn_ligand.sdf', 'data/pdbbind/v2013-core/2vvn/2vvn_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 35, ('data/pdbbind/v2013-core/1qi0/1qi0_ligand.sdf', 'data/pdbbind/v2013-core/1qi0/1qi0_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 36, ('data/pdbbind/v2013-core/3bpc/3bpc_ligand.sdf', 'data/pdbbind/v2013-core/3bpc/3bpc_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 37, ('data/pdbbind/v2013-core/2vw5/2vw5_ligand.sdf', 'data/pdbbind/v2013-core/2vw5/2vw5_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 38, ('data/pdbbind/v2013-core/3muz/3muz_ligand.sdf', 'data/pdbbind/v2013-core/3muz/3muz_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 39, ('data/pdbbind/v2013-core/2xhm/2xhm_ligand.sdf', 'data/pdbbind/v2013-core/2xhm/2xhm_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 40, ('data/pdbbind/v2013-core/3kwa/3kwa_ligand.sdf', 'data/pdbbind/v2013-core/3kwa/3kwa_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 41, ('data/pdbbind/v2013-core/2yge/2yge_ligand.sdf', 'data/pdbbind/v2013-core/2yge/2yge_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 42, ('data/pdbbind/v2013-core/4de2/4de2_ligand.sdf', 'data/pdbbind/v2013-core/4de2/4de2_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 43, ('data/pdbbind/v2013-core/2wca/2wca_ligand.sdf', 'data/pdbbind/v2013-core/2wca/2wca_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 44, ('data/pdbbind/v2013-core/3l7b/3l7b_ligand.sdf', 'data/pdbbind/v2013-core/3l7b/3l7b_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 45, ('data/pdbbind/v2013-core/3ozt/3ozt_ligand.sdf', 'data/pdbbind/v2013-core/3ozt/3ozt_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 46, ('data/pdbbind/v2013-core/1o5b/1o5b_ligand.sdf', 'data/pdbbind/v2013-core/1o5b/1o5b_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 47, ('data/pdbbind/v2013-core/2x8z/2x8z_ligand.sdf', 'data/pdbbind/v2013-core/2x8z/2x8z_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 48, ('data/pdbbind/v2013-core/10gs/10gs_ligand.sdf', 'data/pdbbind/v2013-core/10gs/10gs_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 49, ('data/pdbbind/v2013-core/3ivg/3ivg_ligand.sdf', 'data/pdbbind/v2013-core/3ivg/3ivg_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 50, ('data/pdbbind/v2013-core/3su5/3su5_ligand.sdf', 'data/pdbbind/v2013-core/3su5/3su5_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 51, ('data/pdbbind/v2013-core/2xb8/2xb8_ligand.sdf', 'data/pdbbind/v2013-core/2xb8/2xb8_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 52, ('data/pdbbind/v2013-core/1nvq/1nvq_ligand.sdf', 'data/pdbbind/v2013-core/1nvq/1nvq_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 53, ('data/pdbbind/v2013-core/1oyt/1oyt_ligand.sdf', 'data/pdbbind/v2013-core/1oyt/1oyt_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 54, ('data/pdbbind/v2013-core/1sqa/1sqa_ligand.sdf', 'data/pdbbind/v2013-core/1sqa/1sqa_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 55, ('data/pdbbind/v2013-core/1hnn/1hnn_ligand.sdf', 'data/pdbbind/v2013-core/1hnn/1hnn_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 56, ('data/pdbbind/v2013-core/2xdl/2xdl_ligand.sdf', 'data/pdbbind/v2013-core/2xdl/2xdl_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 57, ('data/pdbbind/v2013-core/3udh/3udh_ligand.sdf', 'data/pdbbind/v2013-core/3udh/3udh_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 58, ('data/pdbbind/v2013-core/2w66/2w66_ligand.sdf', 'data/pdbbind/v2013-core/2w66/2w66_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 59, ('data/pdbbind/v2013-core/3oe5/3oe5_ligand.sdf', 'data/pdbbind/v2013-core/3oe5/3oe5_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 60, ('data/pdbbind/v2013-core/2r23/2r23_ligand.sdf', 'data/pdbbind/v2013-core/2r23/2r23_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 61, ('data/pdbbind/v2013-core/2qft/2qft_ligand.sdf', 'data/pdbbind/v2013-core/2qft/2qft_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 62, ('data/pdbbind/v2013-core/1gpk/1gpk_ligand.sdf', 'data/pdbbind/v2013-core/1gpk/1gpk_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 63, ('data/pdbbind/v2013-core/2gss/2gss_ligand.sdf', 'data/pdbbind/v2013-core/2gss/2gss_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 64, ('data/pdbbind/v2013-core/3su3/3su3_ligand.sdf', 'data/pdbbind/v2013-core/3su3/3su3_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 65, ('data/pdbbind/v2013-core/4djv/4djv_ligand.sdf', 'data/pdbbind/v2013-core/4djv/4djv_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 66, ('data/pdbbind/v2013-core/2j62/2j62_ligand.sdf', 'data/pdbbind/v2013-core/2j62/2j62_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 67, ('data/pdbbind/v2013-core/1sln/1sln_ligand.sdf', 'data/pdbbind/v2013-core/1sln/1sln_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 68, ('data/pdbbind/v2013-core/4djr/4djr_ligand.sdf', 'data/pdbbind/v2013-core/4djr/4djr_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 69, ('data/pdbbind/v2013-core/3f3c/3f3c_ligand.sdf', 'data/pdbbind/v2013-core/3f3c/3f3c_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 70, ('data/pdbbind/v2013-core/3g0w/3g0w_ligand.sdf', 'data/pdbbind/v2013-core/3g0w/3g0w_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 71, ('data/pdbbind/v2013-core/2cbj/2cbj_ligand.sdf', 'data/pdbbind/v2013-core/2cbj/2cbj_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 72, ('data/pdbbind/v2013-core/1yc1/1yc1_ligand.sdf', 'data/pdbbind/v2013-core/1yc1/1yc1_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 73, ('data/pdbbind/v2013-core/1w4o/1w4o_ligand.sdf', 'data/pdbbind/v2013-core/1w4o/1w4o_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 74, ('data/pdbbind/v2013-core/3fk1/3fk1_ligand.sdf', 'data/pdbbind/v2013-core/3fk1/3fk1_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 75, ('data/pdbbind/v2013-core/3g2n/3g2n_ligand.sdf', 'data/pdbbind/v2013-core/3g2n/3g2n_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 76, ('data/pdbbind/v2013-core/3gy4/3gy4_ligand.sdf', 'data/pdbbind/v2013-core/3gy4/3gy4_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 77, ('data/pdbbind/v2013-core/4dew/4dew_ligand.sdf', 'data/pdbbind/v2013-core/4dew/4dew_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# ...
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 168, ('data/pdbbind/v2013-core/3lka/3lka_ligand.sdf', 'data/pdbbind/v2013-core/3lka/3lka_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 169, ('data/pdbbind/v2013-core/3f80/3f80_ligand.sdf', 'data/pdbbind/v2013-core/3f80/3f80_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 170, ('data/pdbbind/v2013-core/3f17/3f17_ligand.sdf', 'data/pdbbind/v2013-core/3f17/3f17_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 171, ('data/pdbbind/v2013-core/3ge7/3ge7_ligand.sdf', 'data/pdbbind/v2013-core/3ge7/3ge7_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 172, ('data/pdbbind/v2013-core/1hfs/1hfs_ligand.sdf', 'data/pdbbind/v2013-core/1hfs/1hfs_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 173, ('data/pdbbind/v2013-core/1zea/1zea_ligand.sdf', 'data/pdbbind/v2013-core/1zea/1zea_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 174, ('data/pdbbind/v2013-core/1n2v/1n2v_ligand.sdf', 'data/pdbbind/v2013-core/1n2v/1n2v_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 175, ('data/pdbbind/v2013-core/2vot/2vot_ligand.sdf', 'data/pdbbind/v2013-core/2vot/2vot_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 176, ('data/pdbbind/v2013-core/1lol/1lol_ligand.sdf', 'data/pdbbind/v2013-core/1lol/1lol_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 177, ('data/pdbbind/v2013-core/1f8c/1f8c_ligand.sdf', 'data/pdbbind/v2013-core/1f8c/1f8c_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 178, ('data/pdbbind/v2013-core/3n7a/3n7a_ligand.sdf', 'data/pdbbind/v2013-core/3n7a/3n7a_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 179, ('data/pdbbind/v2013-core/3gcs/3gcs_ligand.sdf', 'data/pdbbind/v2013-core/3gcs/3gcs_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 180, ('data/pdbbind/v2013-core/2ole/2ole_ligand.sdf', 'data/pdbbind/v2013-core/2ole/2ole_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 181, ('data/pdbbind/v2013-core/2jdu/2jdu_ligand.sdf', 'data/pdbbind/v2013-core/2jdu/2jdu_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 182, ('data/pdbbind/v2013-core/3cft/3cft_ligand.sdf', 'data/pdbbind/v2013-core/3cft/3cft_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 183, ('data/pdbbind/v2013-core/3s8o/3s8o_ligand.sdf', 'data/pdbbind/v2013-core/3s8o/3s8o_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 184, ('data/pdbbind/v2013-core/2iwx/2iwx_ligand.sdf', 'data/pdbbind/v2013-core/2iwx/2iwx_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 185, ('data/pdbbind/v2013-core/2v00/2v00_ligand.sdf', 'data/pdbbind/v2013-core/2v00/2v00_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 186, ('data/pdbbind/v2013-core/3huc/3huc_ligand.sdf', 'data/pdbbind/v2013-core/3huc/3huc_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 187, ('data/pdbbind/v2013-core/2v7a/2v7a_ligand.sdf', 'data/pdbbind/v2013-core/2v7a/2v7a_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 188, ('data/pdbbind/v2013-core/2x0y/2x0y_ligand.sdf', 'data/pdbbind/v2013-core/2x0y/2x0y_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 189, ('data/pdbbind/v2013-core/3uex/3uex_ligand.sdf', 'data/pdbbind/v2013-core/3uex/3uex_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 190, ('data/pdbbind/v2013-core/2pq9/2pq9_ligand.sdf', 'data/pdbbind/v2013-core/2pq9/2pq9_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 191, ('data/pdbbind/v2013-core/1u1b/1u1b_ligand.sdf', 'data/pdbbind/v2013-core/1u1b/1u1b_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)
# Failed to featurize datapoint 192, ('data/pdbbind/v2013-core/4gqq/4gqq_ligand.sdf', 'data/pdbbind/v2013-core/4gqq/4gqq_pocket.pdb'). Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdMolDescriptors.GetMorganFingerprint(tuple, int)
# did not match C++ signature:
#     GetMorganFingerprint(RDKit::ROMol mol, unsigned int radius, boost::python::api::object invariants=[], boost::python::api::object fromAtoms=[], bool useChirality=False, bool useBondTypes=True, bool useFeatures=False, bool useCounts=True, boost::python::api::object bitInfo=None, bool includeRedundantEnvironments=False)

# %%
train_dataset
# Out:
# <DiskDataset X.shape: (154, 0), y.shape: (154,), w.shape: (154,), ids: ['3dd0' '3utu' '2x8z' ... '3f17' '4djv' '1xd0'], task_names: [0]>

# %%
train_dataset.X[10].max()
# Out:
# 0

# %%
# Create and train the model.

n_features = train_dataset.X.shape[1]
model = dc.models.MultitaskRegressor(
        n_tasks=len(tasks),
        n_features=n_features,
        layer_sizes=[2000, 1000],
        dropouts=0.5,
        model_dir="pdbbind_nn",
        learning_rate=0.0003)
model.fit(train_dataset, nb_epoch=50)

# Evaluate it.
metric = dc.metrics.Metric(dc.metrics.pearson_r2_score)
train_scores = model.evaluate(train_dataset, [metric], transformers)
test_scores = model.evaluate(test_dataset, [metric], transformers)
print("Train scores")
print(train_scores)
print("Test scores")
print(test_scores)
# Out:
# ['-logKd/Ki']
